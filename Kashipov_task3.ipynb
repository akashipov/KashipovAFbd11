# %%
from time import time

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from scipy import optimize
from sklearn.metrics import accuracy_score
from sklearn.model_selection import KFold
from sklearn.tree import DecisionTreeClassifier

# %matplotlib inline

# %%
def choice_sub(y, size = 1):
    
    choice = np.zeros(y.shape[0],dtype = bool)
    i = 0
    while (choice[choice == True].shape[0]<size):
        choice[i] = np.random.randint(low = 0,high = 2,size = 1,dtype = bool)
        if i == y.shape[0]-1:
            i=0
        else:
            i += 1
    return y[choice]
sum_ = 0

# %%
a = np.eye(3)

# %%
class MyDecisionTreeClassifier:
    NON_LEAF_TYPE = 0
    LEAF_TYPE = 1

    def __init__(self, min_samples_split=2, max_depth=float('+inf'), sufficient_share=1.0, criterion='gini',\
                 max_features=None):
        self.tree = dict()
        self.min_samples_split = min_samples_split
        self.max_depth = max_depth
        self.sufficient_share = sufficient_share
        self.num_class = -1
        self.find_threshold_v = np.vectorize(self.__find_threshold, signature = '(m),(m)->(),()')
        if criterion == 'gini':
            self.G_function = self.__gini
        elif criterion == 'entropy':
            self.G_function = self.__entropy
        elif criterion == 'misclass':
            self.G_function = self.__misclass
        else:
            print 'invalid criterion name'
            raise

        if max_features == 'sqrt':
            self.get_feature_ids = self.__get_feature_ids_sqrt
        elif max_features == 'log2':
            self.get_feature_ids = self.__get_feature_ids_log2
        elif max_features == None:
            self.get_feature_ids = self.__get_feature_ids_N
        else:
            print 'invalid max_features name'
            raise
        

            
            
            
    def __gini(self, l_c, l_s, r_c, r_s):
        l_s = l_s.astype('float')
        r_s = r_s.astype('float')

        l_gini = 1-(l_c*l_c/(l_s*l_s)).sum(axis=1).reshape(-1,1);
        r_gini = 1-(r_c*r_c/(r_s*r_s)).sum(axis=1).reshape(-1,1); 
        s = l_s[0][0]+r_s[0][0]
        
        return ((l_gini*l_s+r_gini*r_s)/s).reshape(1,-1)[0]    
    
    
    
    
    def __entropy(self, l_c, l_s, r_c, r_s):
        l_s = l_s.astype('float')
        r_s = r_s.astype('float')
        
        l_c = l_c/l_s;
        r_c = r_c/r_s;
        -l_c*np.log2(l_c).sum(axis = 1)
        l_c = np.dot(l_c,np.log(l_c).T)
        r_c = np.dot(r_c,np.log(r_c).T)
        
        s = l_s[0][0]+r_s[0][0]
        
        return (l_s*((-l_c*np.log2(l_c)).sum(axis = 1))+r_s*((-r_c*np.log2(r_c)).sum(axis = 1)))/s

    def __misclass(self, l_c, l_s, r_c, r_s):
        l_s = l_s.astype('float')
        r_s = r_s.astype('float')
        
        l_c = l_c/l_s;
        r_c = r_c/r_s;
        
        s = l_s[0][0]+r_s[0][0]
        
        return (l_s*(1 - np.amax(l_c, axis = 1))+r_s*(1 - np.amax(r_c, axis = 1)))/s

    def __get_feature_ids_sqrt(self, n_feature):
        feature_ids = range(n_feature)
        np.random.shuffle(feature_ids)
        
        return choise_sub(features_id, int(np.sqrt(n_feature)))
        
    def __get_feature_ids_log2(self, n_feature):
        feature_ids = range(n_feature)
        np.random.shuffle(feature_ids)
        return choise_sub(features_id, int(np.log2(n_feature)))

    def __get_feature_ids_N(self, n_feature):
        
        return np.arange(n_feature, dtype = int)
    
    def __sort_samples(self, x, y):
        #print 'x.shape =',x.shape
        #print 'y.shape =',y.shape
        sorted_idx = x.argsort()
        return x[sorted_idx], y[sorted_idx]

    def __div_samples(self, x, y, feature_id, threshold):
        left_mask = x[:, int(feature_id)] > threshold
        right_mask = ~left_mask
        return x[left_mask], x[right_mask], y[left_mask], y[right_mask]

    def __find_threshold(self, x, y):
        
        #Сортирует точки по столбку признаку х. Подсчитывает кол-во уникальных классов
        sorted_x, sorted_y = self.__sort_samples(x, y)
        #print type(sorted_y[0])
        class_number = np.unique(y).shape[0]
        
        # Отрезание по краям массива хвостов длинной self.min_samples_split.
        #Затем проверка оставшейся части на наличие изменений. Если все оставшиеся элементы одинаковы,
        #то возвращаем бесконечность и None, если же разные, то возвращаем массив,который показывает, сколько
        #точек слева при каждом переходе от одного индекса,где произошло изменение класса, к другому
        splitted_sorted_y = sorted_y[self.min_samples_split:-self.min_samples_split]
        r_border_ids = np.where(splitted_sorted_y[:-1] != splitted_sorted_y[1:])[0] + int(self.min_samples_split + 1)
        
        if len(r_border_ids) == 0:
            return float('+inf'), None
        
        #Этот массив, который показывает, так сказать, длительность постоянства класса: [1,1,2,1,3] будет означать, что
        #сначала был один класс, потом он сменился сразу, потом еще раз произошла смена сразу, затем смена произошла через
        #один, смена сразу, смена через два. То есть массив r_border_ids выглядил, например так: [0,1,2,2,3,4,4,4]
        eq_el_count = r_border_ids - np.append([self.min_samples_split], r_border_ids[:-1]) 
        # Создается матрица размером кол-во переходов в splitted_sorted_y * кол-во классов
        one_hot_code = np.zeros((r_border_ids.shape[0], class_number))
        #print one_hot_code.shape
        # Если i-ый переход был сделан из класса j, то в one_hot_code[i][j] ставится 1
        one_hot_code[np.arange(r_border_ids.shape[0],dtype = int), sorted_y[r_border_ids - int(1)]] = 1
        # Каждая строчка умножается на длительность класса, из которого был сделан переход
        class_increments = one_hot_code * eq_el_count.reshape(-1, 1)
        # Это очень странно, но тут прибавляют к первой строке, строку обозначающую кол-во входов каждого класса
        #в начальный хвост !неотсортированного! массива y!(хотя до этого работали с отсорированным), поэтому я тут исправил
        #сортированный....
        class_increments[0] = class_increments[0] + np.bincount(sorted_y[:self.min_samples_split], minlength=class_number)
        
        # Матрица, где i это по сути ползунок, которым мы отсеиваем элементы в левое поддерево, а j это кол-во точек
        #с данным классом в левом поддереве
        l_class_count = np.cumsum(class_increments, axis=0)
        # Тоже самое только для правого дерева
        r_class_count = np.bincount(y) - l_class_count
        # Транспоинровали r_border_ids... столбец, обозначающий кол-во точек в левом поддереве при каждой позиции i ползунка 
        l_sizes = r_border_ids.reshape(l_class_count.shape[0], 1)
        # Тоже самое для правого
        r_sizes = sorted_y.shape[0] - l_sizes
        # Для каждого разбиения находит меру неопределенности, и выбирает разбиение при котором
        #достигается минимум
        gs = self.G_function(l_class_count, l_sizes, r_class_count, r_sizes)
        idx = np.argmin(gs)
    
        #узнается позиция, на которой произошел переход в нашем изначальном массиве и возвращаются две величины:
        #значение меры неопределенности на выбранном разбиении и значение, которое будет использоваться в условии,
        #которое будет разбивать на два поддерева
        left_el_id = l_sizes[idx][0]
        return gs[idx], (sorted_x[left_el_id-1] + sorted_x[left_el_id]) / 2.0

    def __fit_node(self, x, y, node_id, depth, pred_f=-1):
        # Ваш код
        # Необходимо использовать следующее
        sum_h = float(sum_)
        if depth < self.max_depth:
            if float(np.bincount(y,minlength = np.unique(y).shape[0]).max())/float(y.shape[0]) < self.sufficient_share:
                index = self.get_feature_ids(x.shape[1])
                v = np.empty((index.shape[0],2))
                
                v[:,0], v[:,1] = self.find_threshold_v(x[:,index].T,y)

                min_ = v[:,0].argmin()
                if v[min_][0] != float("+inf"):
                    self.tree[node_id] = np.array([0,index[min_],v[min_][1]])
                else:
                    b = np.bincount(y, minlength = np.unique(y).shape[0])
                    self.tree[node_id] = np.array([1,b.argmax(),None])
                    return 
                x_left, x_right,y_left, y_right = self.__div_samples(x,y,self.tree[node_id][1],self.tree[node_id][2])
                if y_left.shape[0] != 0 and y_right.shape[0] != 0:
                    self.__fit_node(x_left, y_left, 2*node_id + 1, depth + 1, pred_f = -1)
                    self.__fit_node(x_right, y_right, 2*node_id + 2, depth + 1, pred_f = -1)
                else:
                    self.tree[node_id][0]=1
                    b = np.bincount(y, minlength = np.unique(y).shape[0])
                    self.tree[node_id][1] = b.argmax()
                    return 
            else:    
                self.tree[node_id] = np.array([1,y[0],None])
                return 
        else:
            b = np.bincount(y, minlength = np.unique(y).shape[0])
            self.tree[node_id] = np.array([1,b.argmax(),None])
            return 
        return 
        pass
    
    def fit(self, x, y):
        self.num_class = np.unique(y).size
        self.__fit_node(x, y, 0, 0) 

    def __predict_class(self, x, node_id):
        node = self.tree[node_id]
        if node[0] == self.__class__.NON_LEAF_TYPE:
            _, feature_id, threshold = node
            if x[int(feature_id)] > threshold:
                return self.__predict_class(x, 2 * node_id + 1)
            else:
                return self.__predict_class(x, 2 * node_id + 2)
        else:
            return node[1]

    def __predict_probs(self, x, node_id):
        node = self.tree[node_id]
        if node[0] == self.__class__.NON_LEAF_TYPE:
            _, feature_id, threshold = node
            if x[int(feature_id)] > threshold:
                return self.__predict_probs(x, 2 * node_id + 1)
            else:
                return self.__predict_probs(x, 2 * node_id + 2)
        else:
            return node[2]
        
    def predict(self, X):
        return np.array([self.__predict_class(x, 0) for x in X])
    
    def predict_probs(self, X):
        return np.array([self.__predict_probs(x, 0) for x in X])

    def fit_predict(self, x_train, y_train, predicted_x):
        self.fit(x_train, y_train)
        return self.predict(predicted_x)

# %%
df = pd.read_csv('./cs-training.csv', sep=',').dropna()
df.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 1                 1                              0.766127   45
# 2                 0                              0.957151   40
# 3                 0                              0.658180   38
# 4                 0                              0.233810   30
# 5                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 1                                     2   0.802982         9120.0
# 2                                     0   0.121876         2600.0
# 3                                     1   0.085113         3042.0
# 4                                     0   0.036050         3300.0
# 5                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 1                               13                        0
# 2                                4                        0
# 3                                2                        1
# 4                                5                        0
# 5                                7                        0
#
#    NumberRealEstateLoansOrLines  NumberOfTime60-89DaysPastDueNotWorse  \
# 1                             6                                     0
# 2                             0                                     0
# 3                             0                                     0
# 4                             0                                     0
# 5                             1                                     0
#
#    NumberOfDependents
# 1                 2.0
# 2                 1.0
# 3                 0.0
# 4                 0.0
# 5                 0.0

# %%
x = df.as_matrix(columns=df.columns[1:])
y = df.as_matrix(columns=df.columns[:1])
y = y.reshape(y.shape[0])
print y.shape
# Out:
# (120269,)

# %%
my_clf = MyDecisionTreeClassifier(min_samples_split=2)
clf = DecisionTreeClassifier(min_samples_split=2)

# %% [markdown]
# ## Проверка скорости работы

# %%
t1 = time()
my_clf.fit(x, y)
t2 = time()
print(t2 - t1)

t1 = time()
clf.fit(x, y)
t2 = time()
print(t2 - t1)
# Out:
# 0.370290994644
# 0.805289983749

# %%
len(my_clf.tree)
# Out:
# 351

# %% [markdown]
# ## Проверка качества работы

# %%
gkf = KFold(n_splits=5, shuffle=True)

# %%
for train, test in gkf.split(x, y):
    X_train, y_train = x[train], y[train]
    X_test, y_test = x[test], y[test]
    my_clf.fit(X_train, y_train)
    a = my_clf.predict(X_test)
    print(accuracy_score(y_pred=a, y_true=y_test))
    #print np.where(a==1)
# Out:
# 0.929408830132
# 0.934065020371
# 0.930614450819
# 0.933025692193
# 0.932149835779

# %%
for train, test in gkf.split(x, y):
    X_train, y_train = x[train], y[train]
    X_test, y_test = x[test], y[test]
    clf.fit(X_train, y_train)
    print(accuracy_score(y_pred=clf.predict(X_test), y_true=y_test))
# Out:
# 0.891244699426
# 0.894030098944
# 0.891036833791
# 0.890787395028
# 0.891531201929

# %%
my_clf.tree
# Out:
# {0: array([ 0.,  6.,  1.]),
#  1: array([ 0.        ,  3.        ,  0.49489722]),
#  2: array([ 1.,  0.,  1.]),
#  3: array([ 0.,  8.,  2.]),
#  4: array([ 0.,  6.,  3.]),
#  5: array([ 0.,  8.,  1.]),
#  6: array([ 0.        ,  0.        ,  0.61676647]),
#  7: array([ 0.       ,  0.       ,  0.9999999]),
#  8: array([ 0.,  2.,  1.]),
#  9: array([  0.,   1.,  27.]),
#  10: array([ 0.,  2.,  2.]),
#  11: array([ 0.        ,  3.        ,  0.04726566]),
#  12: array([ 0.,  2.,  2.]),
#  13: array([ 0.,  2.,  1.]),
#  14: array([ 0.,  8.,  1.]),
#  15: array([1, 1, None], dtype=object),
#  16: array([  0.,   1.,  61.]),
#  17: array([ 0.,  6.,  2.]),
#  18: array([ 0.,  6.,  3.]),
#  19: array([  1.,   1.,  98.]),
#  20: array([ 0.,  5.,  5.]),
#  21: array([ 0.       ,  0.       ,  0.9999999]),
#  22: array([  0.,   1.,  30.]),
#  23: array([ 0.,  9.,  0.]),
#  24: array([ 1.,  0.,  1.]),
#  25: array([ 0.        ,  3.        ,  0.22418237]),
#  26: array([ 0.        ,  0.        ,  0.48627141]),
#  27: array([ 0.,  8.,  1.]),
#  28: array([ 0.,  8.,  1.]),
#  29: array([ 0.,  7.,  0.]),
#  30: array([ 0.,  2.,  1.]),
#  31: array([1, 1, None], dtype=object),
#  32: array([  0.,   1.,  63.]),
#  33: array([1, 0, None], dtype=object),
#  34: array([ 0.,  7.,  1.]),
#  35: array([ 0.        ,  3.        ,  0.51999111]),
#  36: array([    0.,     4.,  1550.]),
#  37: array([ 1.,  1.,  1.]),
#  38: array([ 0.,  9.,  0.]),
#  39: array([ 0.        ,  0.        ,  0.97207972]),
#  40: array([  0.,   1.,  47.]),
#  41: array([1, 1, None], dtype=object),
#  42: array([ 0.,  9.,  2.]),
#  43: array([  0.00000000e+00,   4.00000000e+00,   6.77500000e+03]),
#  44: array([ 0.,  9.,  3.]),
#  45: array([ 0.        ,  0.        ,  1.02195609]),
#  46: array([ 0.,  5.,  0.]),
#  47: array([ 0.        ,  0.        ,  0.33905092]),
#  48: array([ 0.,  8.,  2.]),
#  49: array([ 0.        ,  3.        ,  0.33107661]),
#  50: array([ 0.        ,  3.        ,  0.56539833]),
#  51: array([ 0.,  8.,  0.]),
#  52: array([ 0.,  2.,  5.]),
#  53: array([ 1.,  0.,  2.]),
#  54: array([ 1.,  0.,  1.]),
#  55: array([ 0.        ,  0.        ,  1.00182344]),
#  56: array([ 0.        ,  0.        ,  1.00102602]),
#  57: array([ 0.        ,  0.        ,  0.91407016]),
#  58: array([ 0. ,  8. ,  0.5]),
#  59: array([ 0.,  7.,  3.]),
#  60: array([ 0.,  9.,  0.]),
#  61: array([ 0.,  7.,  9.]),
#  62: array([ 1.,  0.,  1.]),
#  63: array([ 0.        ,  0.        ,  0.55568954]),
#  64: array([ 0.,  2.,  2.]),
#  65: array([1, 0, None], dtype=object),
#  66: array([ 0.,  7.,  0.]),
#  67: array([ 0. ,  2. ,  1.5]),
#  68: array([  0. ,   1. ,  45.5]),
#  69: array([ 0.        ,  3.        ,  0.88877974]),
#  70: array([  0.00000000e+00,   4.00000000e+00,   4.08750000e+03]),
#  71: array([ 0.,  2.,  2.]),
#  72: array([ 0.       ,  0.       ,  0.8872156]),
#  73: array([ 0.        ,  0.        ,  0.21328011]),
#  74: array([ 0.        ,  0.        ,  0.87536533]),
#  75: array([1, 1, None], dtype=object),
#  76: array([    0.,     4.,  1759.]),
#  77: array([  0.00000000e+00,   4.00000000e+00,   7.26650000e+03]),
#  78: array([ 0.,  7.,  1.]),
#  79: array([1, 1, None], dtype=object),
#  80: array([1, 0, None], dtype=object),
#  81: array([ 0.,  2.,  1.]),
#  82: array([1, 0, None], dtype=object),
#  83: array([1, 0, None], dtype=object),
#  84: array([ 0.        ,  0.        ,  0.70831284]),
#  85: array([1, 1, None], dtype=object),
#  86: array([ 0.,  6.,  4.]),
#  87: array([ 0.,  6.,  2.]),
#  88: array([ 0. ,  5. ,  4.5]),
#  89: array([1, 0, None], dtype=object),
#  90: array([ 0.,  5.,  6.]),
#  91: array([ 0.       ,  0.       ,  1.3770815]),
#  92: array([ 0.,  8.,  1.]),
#  93: array([ 0.,  5.,  2.]),
#  94: array([ 0.,  6.,  2.]),
#  95: array([ 0.,  7.,  1.]),
#  96: array([ 0. ,  5. ,  6.5]),
#  97: array([ 0.        ,  0.        ,  0.43904404]),
#  98: array([ 0.,  2.,  5.]),
#  99: array([ 0.       ,  0.       ,  0.9151558]),
#  100: array([  0.,   1.,  29.]),
#  101: array([  0.,   5.,  12.]),
#  102: array([ 0.,  8.,  1.]),
#  103: array([  0.        ,   3.        ,  18.84947518]),
#  104: array([  0.00000000e+00,   4.00000000e+00,   8.16650000e+03]),
#  105: array([1, 1, None], dtype=object),
#  106: array([ 0.,  2.,  4.]),
#  107: array([ 0.,  7.,  2.]),
#  108: array([ 0.,  9.,  4.]),
#  109: array([ 0.        ,  3.        ,  0.64181397]),
#  110: array([  0.,   5.,  11.]),
#  111: array([ 1.,  1.,  0.]),
#  112: array([ 0.,  2.,  2.]),
#  113: array([ 0.,  5.,  9.]),
#  114: array([ 0.        ,  3.        ,  0.56398685]),
#  115: array([  0.,   1.,  41.]),
#  116: array([ 0. ,  7. ,  1.5]),
#  117: array([ 0.        ,  0.        ,  0.95705738]),
#  118: array([ 1.,  0.,  1.]),
#  119: array([ 0. ,  2. ,  1.5]),
#  120: array([  0. ,   1. ,  77.5]),
#  121: array([ 0.,  2.,  1.]),
#  122: array([ 1.,  0.,  0.]),
#  123: array([1, 1, None], dtype=object),
#  124: array([ 1.,  0.,  1.]),
#  125: array([ 0.,  7.,  5.]),
#  126: array([ 0.,  7.,  4.]),
#  127: array([   0.        ,    3.        ,  100.69994596]),
#  128: array([1, 0, None], dtype=object),
#  129: array([  0. ,   1. ,  51.5]),
#  130: array([ 0.,  9.,  0.]),
#  131: array([  0.,   1.,  57.]),
#  132: array([ 1.,  1.,  4.]),
#  41093: array([1, 1, None], dtype=object),
#  41094: array([1, 0, None], dtype=object),
#  135: array([ 0.        ,  3.        ,  0.19699755]),
#  136: array([1, 1, None], dtype=object),
#  41097: array([1, 1, None], dtype=object),
#  41098: array([1, 1, None], dtype=object),
#  139: array([1, 0, None], dtype=object),
#  140: array([1, 1, None], dtype=object),
#  41101: array([1, 1, None], dtype=object),
#  41102: array([ 0.        ,  3.        ,  0.90398118]),
#  143: array([ 0.,  6.,  3.]),
#  144: array([ 1.,  1.,  2.]),
#  145: array([1, 0, None], dtype=object),
#  146: array([1, 1, None], dtype=object),
#  147: array([ 0.,  8.,  0.]),
#  148: array([ 0.        ,  0.        ,  0.15906752]),
#  149: array([ 0.,  2.,  2.]),
#  150: array([1, 0, None], dtype=object),
#  151: array([1, 1, None], dtype=object),
#  152: array([ 0.,  9.,  2.]),
#  153: array([  0.,   1.,  27.]),
#  154: array([ 1.       ,  1.       ,  0.9999999]),
#  155: array([1, 1, None], dtype=object),
#  156: array([ 0.,  5.,  4.]),
#  157: array([    0.,     4.,  3500.]),
#  158: array([ 1.,  1.,  1.]),
#  159: array([  0.,   5.,  17.]),
#  160: array([ 0.,  2.,  1.]),
#  161: array([  0.,   1.,  47.]),
#  162: array([ 0. ,  2. ,  0.5]),
#  163: array([ 0.        ,  0.        ,  0.86384883]),
#  164: array([  0.,   1.,  52.]),
#  165: array([ 0.,  5.,  5.]),
#  166: array([ 0.,  9.,  3.]),
#  167: array([ 0.        ,  0.        ,  0.99883367]),
#  168: array([1, 0, None], dtype=object),
#  169: array([ 0.       ,  3.       ,  2.1904184]),
#  170: array([ 0.,  8.,  0.]),
#  171: array([1, 0, None], dtype=object),
#  172: array([1, 0, None], dtype=object),
#  173: array([ 0.,  5.,  0.]),
#  174: array([ 0.,  9.,  0.]),
#  175: array([1, 0, None], dtype=object),
#  176: array([ 1.,  1.,  2.]),
#  177: array([1, 1, None], dtype=object),
#  178: array([1, 1, None], dtype=object),
#  179: array([1, 0, None], dtype=object),
#  180: array([1, 0, None], dtype=object),
#  41141: array([ 0.,  2.,  4.]),
#  41142: array([ 0.,  9.,  1.]),
#  183: array([  0.,   1.,  46.]),
#  184: array([ 0.,  5.,  7.]),
#  185: array([ 0.,  9.,  3.]),
#  186: array([ 0.        ,  0.        ,  0.74196096]),
#  187: array([ 0.,  7.,  0.]),
#  188: array([ 0.       ,  3.       ,  0.2278138]),
#  189: array([1, 1, None], dtype=object),
#  190: array([  0.,   1.,  24.]),
#  191: array([ 0.,  7.,  2.]),
#  192: array([ 0.,  8.,  2.]),
#  193: array([1, 0, None], dtype=object),
#  194: array([1, 1, None], dtype=object),
#  195: array([  0.00000000e+00,   4.00000000e+00,   8.86000000e+03]),
#  196: array([ 0.      ,  0.      ,  0.089929]),
#  197: array([1, 0, None], dtype=object),
#  198: array([ 0.       ,  0.       ,  0.9999999]),
#  199: array([ 0.        ,  0.        ,  0.94079647]),
#  200: array([ 0.,  8.,  0.]),
#  201: array([ 0.        ,  3.        ,  0.17897505]),
#  202: array([1, 1, None], dtype=object),
#  203: array([ 0.,  7.,  5.]),
#  204: array([    0. ,     4. ,  1155.5]),
#  205: array([  0.,   1.,  53.]),
#  206: array([ 0.,  7.,  1.]),
#  207: array([1, 0, None], dtype=object),
#  208: array([ 0.,  9.,  2.]),
#  209: array([  0.,   1.,  52.]),
#  210: array([ 0.,  9.,  0.]),
#  382: array([1, 1, None], dtype=object),
#  213: array([  0. ,   1. ,  42.5]),
#  214: array([  0. ,   1. ,  53.5]),
#  215: array([ 0.        ,  3.        ,  1.15296553]),
#  216: array([ 0.,  5.,  4.]),
#  217: array([  0.,   1.,  42.]),
#  218: array([ 0.        ,  0.        ,  0.80186608]),
#  219: array([ 1.,  1.,  0.]),
#  220: array([ 1.,  0.,  0.]),
#  221: array([ 0.        ,  3.        ,  0.65340251]),
#  222: array([ 0.,  5.,  1.]),
#  41183: array([ 0.        ,  3.        ,  0.68395675]),
#  41184: array([1, 1, None], dtype=object),
#  225: array([ 0.,  7.,  0.]),
#  226: array([ 0.,  7.,  1.]),
#  227: array([  0.,   1.,  47.]),
#  228: array([ 1.,  0.,  0.]),
#  229: array([ 0.,  7.,  4.]),
#  230: array([ 0.,  2.,  4.]),
#  231: array([ 0.,  7.,  1.]),
#  232: array([ 0.,  2.,  0.]),
#  233: array([ 0.        ,  3.        ,  0.52671552]),
#  234: array([ 1.,  0.,  1.]),
#  235: array([ 0.        ,  3.        ,  0.45783495]),
#  236: array([ 0.        ,  3.        ,  0.04095277]),
#  239: array([1, 0, None], dtype=object),
#  240: array([1, 1, None], dtype=object),
#  241: array([1, 1, None], dtype=object),
#  242: array([ 0.       ,  3.       ,  0.1380724]),
#  243: array([1, 1, None], dtype=object),
#  244: array([ 0.,  9.,  2.]),
#  251: array([  0. ,   5. ,  11.5]),
#  252: array([ 1.,  0.,  1.]),
#  253: array([  0.,   1.,  36.]),
#  254: array([ 0.,  2.,  0.]),
#  255: array([1, 1, None], dtype=object),
#  256: array([1, 1, None], dtype=object),
#  257: array([ 0.        ,  3.        ,  1.12947624]),
#  258: array([ 0.        ,  0.        ,  1.00371028]),
#  259: array([1, 1, None], dtype=object),
#  260: array([1, 1, None], dtype=object),
#  261: array([ 0.        ,  3.        ,  2.37163752]),
#  262: array([ 0.,  8.,  0.]),
#  263: array([1, 1, None], dtype=object),
#  264: array([1, 1, None], dtype=object),
#  265: array([  0.,   1.,  73.]),
#  266: array([  0.00000000e+00,   4.00000000e+00,   1.35410000e+04]),
#  267: array([ 0.,  2.,  2.]),
#  268: array([ 0.        ,  0.        ,  0.19177437]),
#  269: array([ 0.       ,  0.       ,  0.9999999]),
#  270: array([1, 0, None], dtype=object),
#  271: array([1, 1, None], dtype=object),
#  272: array([1, 0, None], dtype=object),
#  275: array([1, 1, None], dtype=object),
#  276: array([1, 1, None], dtype=object),
#  279: array([ 0.        ,  0.        ,  0.84223045]),
#  280: array([1, 1, None], dtype=object),
#  281: array([1, 1, None], dtype=object),
#  282: array([ 0.        ,  3.        ,  0.32505094]),
#  283: array([ 0.,  7.,  1.]),
#  284: array([1, 0, None], dtype=object),
#  82205: array([1, 1, None], dtype=object),
#  82206: array([1, 0, None], dtype=object),
#  287: array([ 0.        ,  0.        ,  0.84860791]),
#  288: array([ 0.,  8.,  0.]),
#  289: array([ 0.        ,  3.        ,  0.46625603]),
#  290: array([ 1.,  1.,  3.]),
#  291: array([1, 0, None], dtype=object),
#  292: array([ 0.,  6.,  2.]),
#  293: array([  1.,   1.,  98.]),
#  294: array([ 0.,  6.,  3.]),
#  295: array([ 0.,  2.,  5.]),
#  296: array([ 0.,  7.,  1.]),
#  297: array([1, 0, None], dtype=object),
#  298: array([1, 1, None], dtype=object),
#  299: array([1, 1, None], dtype=object),
#  300: array([1, 0, None], dtype=object),
#  305: array([1, 0, None], dtype=object),
#  306: array([ 0. ,  6. ,  4.5]),
#  307: array([1, 0, None], dtype=object),
#  308: array([1, 0, None], dtype=object),
#  309: array([  0.,   1.,  36.]),
#  310: array([1, 0, None], dtype=object),
#  311: array([1, 1, None], dtype=object),
#  312: array([1, 1, None], dtype=object),
#  313: array([ 1.,  0.,  2.]),
#  314: array([ 0.,  5.,  3.]),
#  315: array([ 0.        ,  0.        ,  0.59459359]),
#  316: array([ 0.,  2.,  0.]),
#  317: array([1, 1, None], dtype=object),
#  318: array([  0.00000000e+00,   4.00000000e+00,   6.76000000e+03]),
#  319: array([ 0.,  8.,  1.]),
#  320: array([ 0.,  8.,  1.]),
#  321: array([ 1.,  1.,  4.]),
#  322: array([ 0.        ,  0.        ,  0.98344499]),
#  323: array([1, 1, None], dtype=object),
#  324: array([1, 0, None], dtype=object),
#  325: array([ 0.        ,  0.        ,  0.95794557]),
#  326: array([1, 0, None], dtype=object),
#  327: array([1, 0, None], dtype=object),
#  328: array([1, 1, None], dtype=object),
#  329: array([1, 0, None], dtype=object),
#  330: array([1, 0, None], dtype=object),
#  331: array([1, 1, None], dtype=object),
#  332: array([1, 0, None], dtype=object),
#  333: array([ 0. ,  2. ,  0.5]),
#  334: array([ 0.,  7.,  1.]),
#  335: array([1, 1, None], dtype=object),
#  336: array([1, 1, None], dtype=object),
#  339: array([ 0. ,  2. ,  0.5]),
#  340: array([ 0.,  8.,  0.]),
#  341: array([ 0. ,  2. ,  1.5]),
#  342: array([ 1.,  1.,  0.]),
#  347: array([1, 0, None], dtype=object),
#  348: array([  1.,   0.,  27.]),
#  349: array([ 0.        ,  0.        ,  0.85121205]),
#  350: array([ 1.       ,  0.       ,  0.9999999]),
#  353: array([  1.,   1.,  12.]),
#  354: array([ 0.       ,  0.       ,  0.9999999]),
#  355: array([1, 0, None], dtype=object),
#  356: array([ 0.,  2.,  2.]),
#  82277: array([1, 0, None], dtype=object),
#  82278: array([ 1.,  0.,  1.]),
#  359: array([1, 1, None], dtype=object),
#  360: array([1, 0, None], dtype=object),
#  361: array([ 1.,  0.,  1.]),
#  362: array([  0.,   1.,  56.]),
#  82283: array([1, 0, None], dtype=object),
#  82284: array([ 1.,  1.,  4.]),
#  82285: array([1, 0, None], dtype=object),
#  82286: array([  0.00000000e+00,   4.00000000e+00,   4.09150000e+03]),
#  367: array([ 0.        ,  0.        ,  1.75065377]),
#  368: array([    0.,     4.,  2464.]),
#  369: array([ 0.,  5.,  9.]),
#  370: array([ 0.,  2.,  1.]),
#  8563: array([1, 1, None], dtype=object),
#  8564: array([1, 1, None], dtype=object),
#  373: array([ 0.        ,  0.        ,  0.76609516]),
#  374: array([ 0.,  9.,  3.]),
#  375: array([1, 1, None], dtype=object),
#  376: array([ 0.,  2.,  0.]),
#  377: array([1, 1, None], dtype=object),
#  378: array([ 0.,  6.,  2.]),
#  8571: array([1, 0, None], dtype=object),
#  380: array([  0.,   5.,  10.]),
#  8573: array([ 0.        ,  0.        ,  0.84930325]),
#  8574: array([ 0.,  5.,  9.]),
#  383: array([1, 1, None], dtype=object),
#  384: array([ 0. ,  2. ,  3.5]),
#  385: array([ 0.,  8.,  3.]),
#  386: array([  0.00000000e+00,   4.00000000e+00,   6.16650000e+03]),
#  387: array([ 0.,  2.,  4.]),
#  388: array([ 0.        ,  3.        ,  0.50853975]),
#  389: array([1, 0, None], dtype=object),
#  390: array([ 0.,  5.,  7.]),
#  391: array([1, 0, None], dtype=object),
#  392: array([ 0.        ,  3.        ,  0.35264187]),
#  393: array([1, 0, None], dtype=object),
#  394: array([1, 0, None], dtype=object),
#  397: array([ 1.,  1.,  1.]),
#  398: array([ 0.        ,  0.        ,  0.99983692]),
#  399: array([ 0.,  8.,  1.]),
#  400: array([1, 1, None], dtype=object),
#  401: array([ 0.        ,  0.        ,  0.69407833]),
#  402: array([  0.00000000e+00,   4.00000000e+00,   5.37700000e+03]),
#  403: array([ 0.        ,  3.        ,  0.30457314]),
#  404: array([1, 0, None], dtype=object),
#  407: array([ 0.        ,  3.        ,  0.79797814]),
#  408: array([ 0.,  9.,  1.]),
#  409: array([ 0.,  9.,  3.]),
#  410: array([ 0.,  7.,  0.]),
#  411: array([ 1.,  1.,  0.]),
#  412: array([ 0.,  5.,  8.]),
#  413: array([  0.00000000e+00,   4.00000000e+00,   4.32050000e+03]),
#  414: array([  0.,   1.,  57.]),
#  415: array([1, 1, None], dtype=object),
#  416: array([1, 1, None], dtype=object),
#  417: array([ 0.        ,  0.        ,  0.70728859]),
#  418: array([    0.,     4.,  3701.]),
#  419: array([ 0.,  2.,  4.]),
#  420: array([ 1.,  0.,  1.]),
#  421: array([    0. ,     4. ,  3415.5]),
#  422: array([  0.,   1.,  51.]),
#  427: array([1, 1, None], dtype=object),
#  428: array([1, 0, None], dtype=object),
#  429: array([ 0.,  7.,  1.]),
#  430: array([ 0.,  9.,  0.]),
#  431: array([1, 0, None], dtype=object),
#  432: array([1, 0, None], dtype=object),
#  433: array([ 1.,  0.,  1.]),
#  434: array([ 0.        ,  0.        ,  1.11143304]),
#  435: array([ 0. ,  7. ,  1.5]),
#  436: array([1, 1, None], dtype=object),
#  437: array([ 1.,  0.,  4.]),
#  438: array([ 0.        ,  3.        ,  0.02812745]),
#  443: array([  0.,   1.,  58.]),
#  444: array([ 1.,  0.,  5.]),
#  445: array([ 0.       ,  0.       ,  0.9999999]),
#  446: array([ 0.       ,  0.       ,  0.9999999]),
#  82367: array([ 0.        ,  3.        ,  0.79449605]),
#  82368: array([1, 0, None], dtype=object),
#  451: array([ 0.,  8.,  2.]),
#  452: array([  0.,   1.,  30.]),
#  453: array([ 0.        ,  0.        ,  0.78669053]),
#  454: array([ 1.,  0.,  1.]),
#  455: array([ 0.,  7.,  1.]),
#  456: array([ 0.,  9.,  2.]),
#  16382: array([ 1.,  0.,  0.]),
#  459: array([ 0.,  9.,  0.]),
#  460: array([ 0.        ,  3.        ,  0.59665524]),
#  461: array([  0.00000000e+00,   4.00000000e+00,   6.48000000e+03]),
#  462: array([ 0.,  2.,  3.]),
#  463: array([  0.00000000e+00,   4.00000000e+00,   4.46700000e+03]),
#  464: array([ 0.        ,  3.        ,  0.14210945]),
#  465: array([  0. ,   1. ,  29.5]),
#  466: array([ 0.,  9.,  2.]),
#  467: array([1, 1, None], dtype=object),
#  468: array([1, 0, None], dtype=object),
#  471: array([ 0.        ,  3.        ,  0.83013305]),
#  472: array([  0. ,   1. ,  23.5]),
#  473: array([ 0.        ,  3.        ,  0.38036498]),
#  474: array([ 0.       ,  0.       ,  0.8789971]),
#  481: array([  0.00000000e+00,   4.00000000e+00,   1.03250000e+04]),
#  482: array([ 0.,  9.,  0.]),
#  483: array([  0. ,   1. ,  59.5]),
#  484: array([ 1.,  0.,  1.]),
#  485: array([ 1.,  0.,  3.]),
#  486: array([1, 1, None], dtype=object),
#  489: array([ 0.        ,  0.        ,  0.46666952]),
#  490: array([  0.,   1.,  62.]),
#  503: array([ 1.,  0.,  0.]),
#  504: array([1, 1, None], dtype=object),
#  507: array([  0.00000000e+00,   4.00000000e+00,   6.40800000e+03]),
#  508: array([ 0. ,  7. ,  8.5]),
#  509: array([ 1.,  0.,  4.]),
#  510: array([ 0.        ,  3.        ,  0.56836329]),
#  511: array([ 0.       ,  3.       ,  0.6500958]),
#  512: array([ 0.,  2.,  4.]),
#  513: array([1, 1, None], dtype=object),
#  514: array([ 0.,  6.,  3.]),
#  515: array([1, 1, None], dtype=object),
#  516: array([1, 1, None], dtype=object),
#  517: array([1, 1, None], dtype=object),
#  518: array([1, 0, None], dtype=object),
#  519: array([1, 0, None], dtype=object),
#  520: array([1, 0, None], dtype=object),
#  523: array([ 0. ,  9. ,  1.5]),
#  524: array([1, 1, None], dtype=object),
#  525: array([ 0.,  6.,  2.]),
#  526: array([1, 1, None], dtype=object),
#  529: array([1, 0, None], dtype=object),
#  530: array([1, 1, None], dtype=object),
#  531: array([1, 1, None], dtype=object),
#  532: array([ 0. ,  2. ,  3.5]),
#  533: array([1, 0, None], dtype=object),
#  534: array([ 0.,  9.,  2.]),
#  535: array([ 0.,  5.,  7.]),
#  536: array([ 0.,  5.,  9.]),
#  537: array([ 0.,  5.,  4.]),
#  538: array([1, 0, None], dtype=object),
#  539: array([1, 1, None], dtype=object),
#  540: array([1, 1, None], dtype=object),
#  559: array([1, 0, None], dtype=object),
#  560: array([1, 0, None], dtype=object),
#  561: array([1, 1, None], dtype=object),
#  562: array([1, 0, None], dtype=object),
#  565: array([1, 0, None], dtype=object),
#  566: array([1, 0, None], dtype=object),
#  567: array([1, 1, None], dtype=object),
#  568: array([ 1.,  1.,  1.]),
#  569: array([1, 1, None], dtype=object),
#  570: array([1, 1, None], dtype=object),
#  571: array([1, 0, None], dtype=object),
#  572: array([1, 0, None], dtype=object),
#  575: array([1, 1, None], dtype=object),
#  576: array([ 0. ,  7. ,  2.5]),
#  577: array([ 0.,  9.,  3.]),
#  578: array([ 0.,  9.,  2.]),
#  579: array([1, 1, None], dtype=object),
#  580: array([1, 1, None], dtype=object),
#  583: array([    0. ,     4. ,  3674.5]),
#  584: array([ 0.,  5.,  1.]),
#  585: array([ 0.        ,  0.        ,  0.94876549]),
#  586: array([  0. ,   1. ,  51.5]),
#  587: array([1, 0, None], dtype=object),
#  588: array([ 0.        ,  3.        ,  0.03215463]),
#  589: array([ 0.,  6.,  4.]),
#  590: array([  0.00000000e+00,   4.00000000e+00,   7.73400000e+03]),
#  591: array([1, 0, None], dtype=object),
#  592: array([ 1.,  1.,  5.]),
#  593: array([1, 1, None], dtype=object),
#  594: array([ 1.,  1.,  2.]),
#  595: array([1, 0, None], dtype=object),
#  596: array([1, 0, None], dtype=object),
#  597: array([1, 0, None], dtype=object),
#  598: array([  1.,   1.,  98.]),
#  613: array([1, 0, None], dtype=object),
#  614: array([ 0.,  5.,  8.]),
#  615: array([1, 0, None], dtype=object),
#  616: array([ 0.       ,  0.       ,  0.9999999]),
#  619: array([ 0.        ,  0.        ,  0.93440828]),
#  620: array([ 0.        ,  0.        ,  0.65574315]),
#  621: array([1, 0, None], dtype=object),
#  622: array([1, 1, None], dtype=object),
#  627: array([ 0.,  9.,  0.]),
#  628: array([ 0.       ,  0.       ,  0.4262838]),
#  629: array([ 0. ,  8. ,  0.5]),
#  630: array([ 0.,  8.,  0.]),
#  631: array([1, 1, None], dtype=object),
#  632: array([1, 1, None], dtype=object),
#  633: array([1, 0, None], dtype=object),
#  634: array([  0.,   1.,  49.]),
#  635: array([ 0.,  2.,  2.]),
#  636: array([    0. ,     4. ,  3308.5]),
#  637: array([ 0.,  6.,  5.]),
#  638: array([ 0.,  2.,  0.]),
#  639: array([1, 1, None], dtype=object),
#  640: array([  0.00000000e+00,   4.00000000e+00,   6.10350000e+03]),
#  641: array([ 0.        ,  3.        ,  0.41043612]),
#  642: array([ 0.,  2.,  2.]),
#  645: array([ 1.,  0.,  1.]),
#  646: array([ 0.        ,  3.        ,  0.18407101]),
#  651: array([1, 0, None], dtype=object),
#  652: array([1, 1, None], dtype=object),
#  653: array([1, 1, None], dtype=object),
#  654: array([ 1.,  1.,  3.]),
#  667: array([1, 1, None], dtype=object),
#  668: array([1, 1, None], dtype=object),
#  669: array([ 0.,  6.,  5.]),
#  670: array([ 0.,  9.,  0.]),
#  679: array([1, 1, None], dtype=object),
#  680: array([1, 0, None], dtype=object),
#  681: array([    0.,     4.,  3010.]),
#  682: array([ 0.,  6.,  9.]),
#  683: array([1, 0, None], dtype=object),
#  684: array([  0.00000000e+00,   4.00000000e+00,   4.67250000e+03]),
#  685: array([1, 0, None], dtype=object),
#  686: array([    0.,     4.,  2780.]),
#  32757: array([ 0.,  0.,  0.]),
#  700: array([1, 0, None], dtype=object),
#  707: array([1, 1, None], dtype=object),
#  708: array([  0.00000000e+00,   4.00000000e+00,   4.91250000e+03]),
#  709: array([1, 1, None], dtype=object),
#  710: array([ 0. ,  5. ,  2.5]),
#  713: array([ 0.,  7.,  0.]),
#  714: array([ 0. ,  5. ,  8.5]),
#  715: array([1, 0, None], dtype=object),
#  716: array([ 0.        ,  3.        ,  0.07922401]),
#  717: array([1, 1, None], dtype=object),
#  718: array([1, 1, None], dtype=object),
#  725: array([ 0.        ,  0.        ,  0.92254912]),
#  726: array([ 0.,  7.,  0.]),
#  727: array([ 0.        ,  0.        ,  0.87355204]),
#  728: array([ 0.,  7.,  2.]),
#  729: array([ 0.,  5.,  8.]),
#  730: array([  0.,   5.,  10.]),
#  731: array([   0.,    4.,  923.]),
#  732: array([ 0.,  7.,  0.]),
#  164573: array([1, 0, None], dtype=object),
#  164574: array([1, 1, None], dtype=object),
#  735: array([1, 1, None], dtype=object),
#  736: array([1, 0, None], dtype=object),
#  737: array([  0.,   1.,  45.]),
#  738: array([1, 1, None], dtype=object),
#  739: array([1, 1, None], dtype=object),
#  740: array([  0. ,   1. ,  37.5]),
#  741: array([1, 1, None], dtype=object),
#  742: array([ 0.,  2.,  0.]),
#  743: array([1, 0, None], dtype=object),
#  744: array([ 0.       ,  0.       ,  0.9999999]),
#  745: array([ 1.,  1.,  3.]),
#  746: array([1, 0, None], dtype=object),
#  747: array([  0.,   5.,  11.]),
#  748: array([1, 1, None], dtype=object),
#  749: array([  0.,   1.,  40.]),
#  750: array([ 0.,  2.,  0.]),
#  751: array([1, 1, None], dtype=object),
#  752: array([1, 1, None], dtype=object),
#  753: array([ 0.,  5.,  3.]),
#  754: array([ 0.,  6.,  2.]),
#  755: array([  0. ,   1. ,  41.5]),
#  756: array([ 0.,  7.,  1.]),
#  757: array([ 1.       ,  1.       ,  0.9999999]),
#  758: array([ 0.        ,  3.        ,  0.11176752]),
#  759: array([  0.,   1.,  30.]),
#  760: array([ 1.,  0.,  0.]),
#  17145: array([1, 1, None], dtype=object),
#  17146: array([1, 1, None], dtype=object),
#  17147: array([1, 1, None], dtype=object),
#  17148: array([1, 1, None], dtype=object),
#  17149: array([1, 1, None], dtype=object),
#  17150: array([1, 0, None], dtype=object),
#  769: array([1, 1, None], dtype=object),
#  770: array([ 0.,  2.,  2.]),
#  4193067: array([ 0.        ,  0.        ,  0.10321921]),
#  772: array([ 1.,  1.,  1.]),
#  773: array([ 0.       ,  3.       ,  0.3549258]),
#  774: array([ 0.        ,  0.        ,  0.81996092]),
#  775: array([1, 0, None], dtype=object),
#  776: array([ 0.        ,  0.        ,  1.02015276]),
#  777: array([1, 1, None], dtype=object),
#  778: array([ 0.        ,  0.        ,  1.07614611]),
#  781: array([ 0.        ,  3.        ,  0.34151713]),
#  782: array([ 0.,  9.,  0.]),
#  785: array([1, 1, None], dtype=object),
#  786: array([  0.,   1.,  33.]),
#  23343: array([1, 1, None], dtype=object),
#  797: array([ 1.       ,  0.       ,  0.9999999]),
#  798: array([  0. ,   1. ,  61.5]),
#  799: array([1, 1, None], dtype=object),
#  800: array([ 0.,  7.,  0.]),
#  6960: array([ 1.,  0.,  1.]),
#  803: array([    0.,     4.,  2805.]),
#  804: array([ 0.        ,  3.        ,  0.55114876]),
#  805: array([  0. ,   5. ,  20.5]),
#  806: array([  0.,   5.,  11.]),
#  807: array([1, 0, None], dtype=object),
#  808: array([  0.00000000e+00,   4.00000000e+00,   1.10000000e+04]),
#  815: array([1, 1, None], dtype=object),
#  816: array([1, 1, None], dtype=object),
#  817: array([ 1.,  1.,  0.]),
#  818: array([ 0.,  9.,  0.]),
#  819: array([ 0.        ,  3.        ,  1.02268202]),
#  820: array([ 0.,  7.,  0.]),
#  821: array([1, 0, None], dtype=object),
#  822: array([ 0.,  4.,  0.]),
#  137: array([1, 0, None], dtype=object),
#  825: array([ 1.,  1.,  0.]),
#  826: array([  0.,   1.,  29.]),
#  827: array([ 1.,  0.,  0.]),
#  828: array([ 0.,  8.,  0.]),
#  829: array([ 1.,  0.,  0.]),
#  830: array([ 1.,  0.,  0.]),
#  835: array([1, 1, None], dtype=object),
#  836: array([1, 1, None], dtype=object),
#  837: array([    0.,     4.,  3963.]),
#  838: array([ 0.,  9.,  0.]),
#  839: array([1, 0, None], dtype=object),
#  840: array([ 0.        ,  0.        ,  0.56088301]),
#  843: array([ 0.,  2.,  4.]),
#  844: array([    0. ,     4. ,  2603.5]),
#  845: array([  0.00000000e+00,   4.00000000e+00,   5.55000000e+03]),
#  846: array([ 0.        ,  3.        ,  0.35135445]),
#  141: array([1, 1, None], dtype=object),
#  142: array([    0. ,     4. ,  2292.5]),
#  855: array([ 1.,  0.,  0.]),
#  856: array([ 0.,  9.,  2.]),
#  857: array([1, 0, None], dtype=object),
#  858: array([ 1.,  0.,  0.]),
#  859: array([1, 0, None], dtype=object),
#  860: array([ 1.,  0.,  1.]),
#  861: array([ 1.,  0.,  4.]),
#  862: array([ 1.,  0.,  1.]),
#  23355: array([1, 0, None], dtype=object),
#  869: array([  0.,   1.,  24.]),
#  870: array([  0. ,   1. ,  55.5]),
#  871: array([1, 0, None], dtype=object),
#  872: array([ 0.        ,  3.        ,  0.25090027]),
#  23356: array([1, 0, None], dtype=object),
#  877: array([  0. ,   5. ,  25.5]),
#  878: array([ 0.       ,  3.       ,  0.0211649]),
#  4193085: array([1, 0, None], dtype=object),
#  4193086: array([1, 0, None], dtype=object),
#  887: array([ 1.,  0.,  0.]),
#  888: array([ 0.        ,  0.        ,  1.20328538]),
#  891: array([  0.00000000e+00,   4.00000000e+00,   4.39300000e+03]),
#  892: array([  0.,   1.,  60.]),
#  893: array([ 0.       ,  3.       ,  0.0076643]),
#  894: array([ 0.,  5.,  0.]),
#  164735: array([1, 0, None], dtype=object),
#  164736: array([1, 1, None], dtype=object),
#  903: array([  0. ,   1. ,  40.5]),
#  904: array([ 0.        ,  3.        ,  0.77174032]),
#  905: array([ 1.,  0.,  0.]),
#  906: array([1, 1, None], dtype=object),
#  907: array([ 0. ,  9. ,  0.5]),
#  908: array([1, 0, None], dtype=object),
#  911: array([ 0.        ,  3.        ,  0.66521978]),
#  912: array([ 0.,  8.,  0.]),
#  913: array([1, 1, None], dtype=object),
#  914: array([ 1.,  1.,  2.]),
#  919: array([1, 1, None], dtype=object),
#  920: array([ 0.        ,  3.        ,  1.24321898]),
#  921: array([ 0.        ,  3.        ,  2.64820628]),
#  922: array([ 0.        ,  0.        ,  0.99946032]),
#  923: array([ 0.        ,  3.        ,  0.30239926]),
#  924: array([ 0.,  9.,  1.]),
#  925: array([ 0.        ,  3.        ,  0.29966384]),
#  926: array([ 1.,  0.,  3.]),
#  927: array([ 0.        ,  0.        ,  0.98976073]),
#  928: array([1, 0, None], dtype=object),
#  14761: array([ 0.,  2.,  2.]),
#  930: array([ 0.       ,  0.       ,  0.9999999]),
#  931: array([ 0.,  5.,  5.]),
#  932: array([1, 0, None], dtype=object),
#  933: array([1, 1, None], dtype=object),
#  934: array([ 0.        ,  0.        ,  1.01625772]),
#  943: array([ 0.,  2.,  0.]),
#  944: array([ 0.        ,  3.        ,  0.77365087]),
#  945: array([  0.,   5.,  10.]),
#  946: array([1, 1, None], dtype=object),
#  947: array([ 0.,  7.,  2.]),
#  948: array([ 0.        ,  3.        ,  0.16296879]),
#  949: array([ 0.        ,  0.        ,  0.92931385]),
#  950: array([  0. ,   1. ,  29.5]),
#  963: array([ 1.,  1.,  0.]),
#  964: array([ 0.,  5.,  8.]),
#  965: array([ 1.,  0.,  1.]),
#  966: array([    0.,     4.,  2225.]),
#  967: array([  0.,   1.,  61.]),
#  968: array([1, 0, None], dtype=object),
#  971: array([1, 0, None], dtype=object),
#  972: array([1, 0, None], dtype=object),
#  979: array([1, 1, None], dtype=object),
#  980: array([1, 0, None], dtype=object),
#  981: array([1, 1, None], dtype=object),
#  982: array([ 0.       ,  0.       ,  0.4351403]),
#  1015: array([  0.,   5.,  11.]),
#  1016: array([  0.00000000e+00,   4.00000000e+00,   6.33650000e+03]),
#  1017: array([1, 1, None], dtype=object),
#  1018: array([ 0.,  9.,  1.]),
#  1021: array([ 0.,  7.,  3.]),
#  1022: array([  0.,   5.,  48.]),
#  1023: array([1, 1, None], dtype=object),
#  1024: array([ 0. ,  8. ,  0.5]),
#  1025: array([1, 0, None], dtype=object),
#  1026: array([  0.,   5.,  14.]),
#  1029: array([ 1.,  1.,  1.]),
#  1030: array([ 0.        ,  0.        ,  1.01027477]),
#  15191: array([1, 1, None], dtype=object),
#  1047: array([1, 0, None], dtype=object),
#  1048: array([1, 0, None], dtype=object),
#  1051: array([1, 1, None], dtype=object),
#  1052: array([ 1.,  0.,  2.]),
#  41137: array([1, 1, None], dtype=object),
#  1065: array([1, 1, None], dtype=object),
#  1066: array([1, 0, None], dtype=object),
#  1543: array([ 0.        ,  3.        ,  0.53940782]),
#  41138: array([ 0.,  6.,  1.]),
#  1070: array([ 0.,  7.,  1.]),
#  1071: array([  0.00000000e+00,   4.00000000e+00,   9.16500000e+03]),
#  1072: array([1, 0, None], dtype=object),
#  1073: array([  0.,   5.,  12.]),
#  1074: array([1, 1, None], dtype=object),
#  1075: array([1, 1, None], dtype=object),
#  1076: array([ 0.        ,  3.        ,  0.73513686]),
#  181: array([ 0.,  9.,  0.]),
#  182: array([ 0.,  2.,  5.]),
#  1133: array([1, 0, None], dtype=object),
#  1134: array([1, 1, None], dtype=object),
#  1145: array([  0.,   1.,  42.]),
#  1146: array([  0.00000000e+00,   4.00000000e+00,   5.21100000e+03]),
#  1153: array([1, 1, None], dtype=object),
#  1154: array([1, 0, None], dtype=object),
#  1155: array([1, 1, None], dtype=object),
#  1156: array([ 1.,  0.,  3.]),
#  1157: array([1, 1, None], dtype=object),
#  1158: array([    0. ,     4. ,  2519.5]),
#  1167: array([  0. ,   1. ,  64.5]),
#  1168: array([1, 1, None], dtype=object),
#  1169: array([ 0.,  2.,  2.]),
#  1170: array([ 1.,  0.,  1.]),
#  1171: array([1, 0, None], dtype=object),
#  1172: array([ 0.        ,  0.        ,  0.80384297]),
#  1173: array([  0.00000000e+00,   4.00000000e+00,   6.25000000e+03]),
#  1174: array([  0.,   5.,  12.]),
#  1177: array([1, 0, None], dtype=object),
#  1178: array([1, 0, None], dtype=object),
#  1179: array([ 0.        ,  3.        ,  0.25731289]),
#  1180: array([ 0.        ,  0.        ,  0.68863919]),
#  1181: array([ 0.,  5.,  9.]),
#  1182: array([  1.,   1.,  10.]),
#  1229: array([1, 1, None], dtype=object),
#  1230: array([  0.00000000e+00,   4.00000000e+00,   8.82450000e+03]),
#  1233: array([1, 0, None], dtype=object),
#  1234: array([ 0.,  7.,  1.]),
#  25813: array([1, 1, None], dtype=object),
#  25814: array([  0.,   5.,  14.]),
#  1239: array([1, 1, None], dtype=object),
#  1240: array([1, 0, None], dtype=object),
#  1241: array([1, 0, None], dtype=object),
#  1242: array([1, 1, None], dtype=object),
#  9439: array([1, 1, None], dtype=object),
#  9440: array([1, 1, None], dtype=object),
#  1255: array([ 0.        ,  3.        ,  0.24354476]),
#  1256: array([ 0.        ,  0.        ,  0.76469463]),
#  1257: array([1, 1, None], dtype=object),
#  1258: array([  0. ,   1. ,  67.5]),
#  1259: array([1, 1, None], dtype=object),
#  1260: array([1, 0, None], dtype=object),
#  9453: array([ 0.       ,  0.       ,  0.9999999]),
#  9454: array([1, 0, None], dtype=object),
#  1265: array([ 0.       ,  3.       ,  0.4977976]),
#  1266: array([ 1.,  1.,  2.]),
#  1269: array([1, 1, None], dtype=object),
#  1270: array([1, 0, None], dtype=object),
#  1271: array([ 0.,  5.,  7.]),
#  1272: array([    0.,     4.,  3904.]),
#  1273: array([1, 0, None], dtype=object),
#  1274: array([1, 1, None], dtype=object),
#  1275: array([1, 1, None], dtype=object),
#  1276: array([ 0.        ,  0.        ,  0.66497409]),
#  1277: array([ 0.,  6.,  3.]),
#  1278: array([ 1.,  1.,  0.]),
#  1281: array([1, 0, None], dtype=object),
#  1282: array([1, 1, None], dtype=object),
#  1283: array([ 0.       ,  0.       ,  0.7369724]),
#  1284: array([ 0.        ,  3.        ,  0.36379427]),
#  1285: array([  0.,   5.,  14.]),
#  1286: array([ 0.,  5.,  6.]),
#  1293: array([1, 1, None], dtype=object),
#  1294: array([1, 1, None], dtype=object),
#  1303: array([1, 1, None], dtype=object),
#  1304: array([1, 0, None], dtype=object),
#  1305: array([ 0.,  8.,  1.]),
#  1306: array([ 0.,  8.,  1.]),
#  16770341: array([  0.,   1.,  60.]),
#  16770342: array([  0. ,   1. ,  57.5]),
#  25909: array([1, 0, None], dtype=object),
#  25910: array([1, 0, None], dtype=object),
#  1339: array([1, 0, None], dtype=object),
#  1340: array([ 0.,  9.,  1.]),
#  1341: array([ 0.        ,  3.        ,  0.04477046]),
#  1342: array([    0. ,     4. ,  3463.5]),
#  30263: array([1, 0, None], dtype=object),
#  30264: array([1, 0, None], dtype=object),
#  1363: array([ 0.,  5.,  1.]),
#  1364: array([ 0.,  6.,  4.]),
#  1365: array([1, 0, None], dtype=object),
#  1366: array([ 1.,  1.,  0.]),
#  1367: array([ 0.        ,  3.        ,  0.40500431]),
#  1368: array([ 0.,  7.,  1.]),
#  1369: array([ 0.,  5.,  6.]),
#  1370: array([ 0.        ,  0.        ,  0.02894212]),
#  1371: array([ 0.,  8.,  1.]),
#  1372: array([    0.,     4.,  2393.]),
#  1373: array([ 1.,  0.,  0.]),
#  1374: array([  0. ,   1. ,  27.5]),
#  1417: array([  0.00000000e+00,   4.00000000e+00,   7.56300000e+03]),
#  1418: array([1, 0, None], dtype=object),
#  1421: array([ 0.,  5.,  4.]),
#  1422: array([1, 1, None], dtype=object),
#  1427: array([1, 1, None], dtype=object),
#  1428: array([  0.00000000e+00,   4.00000000e+00,   6.29850000e+03]),
#  1429: array([1, 0, None], dtype=object),
#  1430: array([ 0.        ,  3.        ,  0.41587907]),
#  1433: array([1, 0, None], dtype=object),
#  1434: array([  0. ,   1. ,  28.5]),
#  1451: array([ 0. ,  2. ,  3.5]),
#  1452: array([  0. ,   5. ,  16.5]),
#  1453: array([ 0.        ,  3.        ,  0.41548952]),
#  1454: array([ 0.,  2.,  2.]),
#  1455: array([1, 0, None], dtype=object),
#  1456: array([1, 0, None], dtype=object),
#  1457: array([1, 0, None], dtype=object),
#  1458: array([  0.00000000e+00,   4.00000000e+00,   1.62390000e+04]),
#  1459: array([1, 1, None], dtype=object),
#  1460: array([  0.00000000e+00,   4.00000000e+00,   8.23900000e+03]),
#  1461: array([ 1.,  0.,  0.]),
#  1462: array([ 0.        ,  0.        ,  0.76186395]),
#  1463: array([ 1.,  0.,  1.]),
#  1464: array([ 1.,  0.,  1.]),
#  1465: array([ 0.,  2.,  0.]),
#  1466: array([ 0.,  2.,  0.]),
#  1467: array([  0.,   1.,  36.]),
#  1468: array([ 0.        ,  3.        ,  0.04221919]),
#  1469: array([1, 1, None], dtype=object),
#  1470: array([1, 1, None], dtype=object),
#  1475: array([1, 1, None], dtype=object),
#  1476: array([ 0.       ,  3.       ,  0.1098114]),
#  1481: array([1, 0, None], dtype=object),
#  1482: array([1, 1, None], dtype=object),
#  1485: array([  0.00000000e+00,   4.00000000e+00,   4.05000000e+03]),
#  1486: array([  0.00000000e+00,   4.00000000e+00,   6.33650000e+03]),
#  1489: array([1, 0, None], dtype=object),
#  1490: array([1, 1, None], dtype=object),
#  1495: array([ 0.        ,  0.        ,  0.93280248]),
#  1496: array([ 0.        ,  3.        ,  0.22623682]),
#  1497: array([ 0.        ,  3.        ,  0.20111593]),
#  1498: array([1, 0, None], dtype=object),
#  1499: array([1, 0, None], dtype=object),
#  1500: array([1, 1, None], dtype=object),
#  1501: array([ 0.,  7.,  0.]),
#  1502: array([ 1.,  0.,  0.]),
#  1507: array([ 1.,  1.,  3.]),
#  1508: array([ 0.        ,  0.        ,  0.85810019]),
#  1509: array([ 1.,  1.,  0.]),
#  1510: array([ 1.,  0.,  0.]),
#  1511: array([1, 1, None], dtype=object),
#  1512: array([1, 0, None], dtype=object),
#  1513: array([1, 1, None], dtype=object),
#  1514: array([ 1.,  1.,  1.]),
#  1517: array([ 0.,  5.,  1.]),
#  1518: array([ 0.,  5.,  1.]),
#  1519: array([ 0.,  6.,  2.]),
#  1520: array([ 0. ,  9. ,  1.5]),
#  1521: array([  0.00000000e+00,   4.00000000e+00,   4.01400000e+03]),
#  1522: array([ 0.,  7.,  0.]),
#  1523: array([ 0.        ,  0.        ,  0.18387311]),
#  1524: array([  0. ,   1. ,  35.5]),
#  1525: array([ 0.,  5.,  0.]),
#  1526: array([ 0.,  5.,  6.]),
#  1541: array([1, 0, None], dtype=object),
#  1542: array([ 1.,  1.,  2.]),
#  65519: array([1, 0, None], dtype=object),
#  1544: array([ 0.        ,  0.        ,  0.99566601]),
#  1547: array([1, 0, None], dtype=object),
#  1548: array([1, 1, None], dtype=object),
#  1549: array([ 0.,  5.,  4.]),
#  1550: array([ 0.        ,  0.        ,  0.63393303]),
#  1553: array([1, 0, None], dtype=object),
#  1554: array([1, 0, None], dtype=object),
#  1557: array([1, 0, None], dtype=object),
#  1558: array([1, 0, None], dtype=object),
#  1563: array([ 0.,  9.,  0.]),
#  1564: array([ 0.        ,  0.        ,  1.06406587]),
#  1565: array([1, 1, None], dtype=object),
#  1566: array([  0. ,   1. ,  56.5]),
#  1573: array([ 0.        ,  0.        ,  0.99965035]),
#  1574: array([1, 1, None], dtype=object),
#  1595: array([1, 0, None], dtype=object),
#  1596: array([1, 1, None], dtype=object),
#  1597: array([ 0.       ,  3.       ,  0.5174092]),
#  1598: array([ 1.,  1.,  1.]),
#  1601: array([ 1.,  0.,  0.]),
#  1602: array([    0.,     4.,  2126.]),
#  1607: array([ 0.        ,  0.        ,  0.87300551]),
#  1608: array([1, 1, None], dtype=object),
#  1609: array([1, 1, None], dtype=object),
#  1610: array([1, 0, None], dtype=object),
#  1611: array([1, 0, None], dtype=object),
#  1612: array([  0.00000000e+00,   4.00000000e+00,   7.25000000e+03]),
#  1613: array([1, 0, None], dtype=object),
#  1614: array([ 1.,  0.,  0.]),
#  1617: array([1, 0, None], dtype=object),
#  1618: array([ 0.        ,  0.        ,  0.91182658]),
#  910933: array([1, 0, None], dtype=object),
#  910934: array([ 0.        ,  3.        ,  0.75897417]),
#  1637: array([  0.00000000e+00,   4.00000000e+00,   7.75000000e+03]),
#  1638: array([ 0.        ,  0.        ,  0.91061072]),
#  1639: array([1, 1, None], dtype=object),
#  1640: array([ 0.       ,  0.       ,  0.9043172]),
#  1641: array([ 0.        ,  0.        ,  0.98750271]),
#  1642: array([ 0.        ,  3.        ,  0.65346783]),
#  1645: array([1, 0, None], dtype=object),
#  1646: array([1, 0, None], dtype=object),
#  1653: array([ 1.,  0.,  0.]),
#  1654: array([1, 1, None], dtype=object),
#  1657: array([1, 0, None], dtype=object),
#  1658: array([ 0.,  2.,  2.]),
#  1675: array([ 0.,  2.,  3.]),
#  1676: array([1, 0, None], dtype=object),
#  1677: array([ 1.,  1.,  1.]),
#  1678: array([    0.,     4.,  1750.]),
#  1681: array([1, 1, None], dtype=object),
#  1682: array([1, 0, None], dtype=object),
#  1687: array([ 0.        ,  0.        ,  0.47002249]),
#  1688: array([ 0.,  7.,  2.]),
#  1689: array([1, 0, None], dtype=object),
#  1690: array([ 0.,  2.,  4.]),
#  1691: array([ 1.,  1.,  1.]),
#  1692: array([  0. ,   1. ,  62.5]),
#  1693: array([ 0.        ,  3.        ,  0.81364609]),
#  1694: array([1, 0, None], dtype=object),
#  59041: array([1, 0, None], dtype=object),
#  59042: array([ 0.,  9.,  0.]),
#  59047: array([1, 0, None], dtype=object),
#  59048: array([1, 1, None], dtype=object),
#  59049: array([  0.,   1.,  55.]),
#  59050: array([ 0.        ,  0.        ,  0.72209734]),
#  59051: array([  0.,   1.,  39.]),
#  59052: array([1, 1, None], dtype=object),
#  26285: array([1, 0, None], dtype=object),
#  26286: array([  0. ,   1. ,  49.5]),
#  285: array([ 0.,  5.,  9.]),
#  1713: array([  0.,   5.,  18.]),
#  1714: array([  0.00000000e+00,   4.00000000e+00,   6.50000000e+03]),
#  286: array([1, 1, None], dtype=object),
#  1723: array([1, 0, None], dtype=object),
#  1724: array([ 0.        ,  3.        ,  0.10215557]),
#  1725: array([1, 0, None], dtype=object),
#  1726: array([1, 1, None], dtype=object),
#  1739: array([ 0.        ,  0.        ,  1.14893958]),
#  1740: array([1, 1, None], dtype=object),
#  1741: array([  0. ,   1. ,  59.5]),
#  1742: array([  0.00000000e+00,   4.00000000e+00,   5.59250000e+03]),
#  1745: array([1, 1, None], dtype=object),
#  1746: array([1, 0, None], dtype=object),
#  95865: array([  0.,   1.,  39.]),
#  ...}
